# %% [markdown]
# # Examen Módulo 2 - Montecarlo - 4.
#
# **Mantenga la calma y lea cuidadosamente las siguientes indicaciones antes de comenzar el examen:**
# - Para resolver el examen edite este mismo archivo y renómbrelo de la siguiente manera: *Examen2_ApellidoNombre*, donde *ApellidoNombre* corresponde a su apellido paterno con la inicial en mayúscula, seguido de su primer nombre con la inicial en mayúscula **sin acentos**. Por ejemplo, en mi caso el nombre del archivo sería *Examen2_ArellanoCarlos*.
# - Resuelva los puntos en el espacio provisto. Si requiere agregar más celdas para código o escritura, hágalo (`Esc`+`B`) o (`Esc`+`A`).
# - Recuerde que también se está evaluando su capacidad de interpretar los resultados. Escriba sus interpretaciones/conclusiones en celdas utilizando *Markdown*.
# - El formato de presentación de todo el examen en general debe ser adecuado. Use tamaños de letra, colores, etiquetas, etcétera.
# - No se resuelven dudas de ningún tipo por los profesores de la asignatura. Por favor absténgase de preguntar.

# %% [markdown]
# # Examen 4 Dominguez Juan Pablo

# %% [markdown]
# ---
# ### Integración Montecarlo tipo 1 <font size='1'>(25 puntos)</font>
#
# Encuentre los valores de $y(0.3)$, $y(0.5)$, $y(0.7)$, $y(0.9)$ y $y(1.1)$, conociendo $y(0.1)=0.1$ y su derivada
# $$
# \frac{dy}{dx}=\frac{\ln(2+\sin(2x^2))}{xe^{-x^3}},\quad y(0.1)=0.1
# $$
#
# Para cada intervalo: $(0.1\leq x\leq0.3)$, $(0.3\leq x\leq0.5)$, $(0.5\leq x\leq0.7)$, $(0.7\leq x\leq0.9)$ y $(0.9\leq x\leq1.1)$ use integración Montecarlo de tipo 1 con $10^6$ puntos.

# %%
import numpy as np
from scipy.integrate import quad

# Definir la función a integrar
def f(x):
    return (np.log(2 + np.sin(2*x**2)))/(x*np.e**-x**3)

# Definir los límites de integración
a = 0.1
b = 1.1

# Calcular la integral
integral, error = quad(f, a, b)

# Imprimir el resultado
print("El valor de la integral es:", integral)
# Out:
# El valor de la integral es: 2.710085411036241

# %% [markdown]
# ###  Aqui manipule la integral para conocer los valores de los integrales

# %% [markdown]
# 1. Escriba la función de integración Montecarlo de tipo 1, con argumentos de entrada $f$, $a$, $b$ y $N$. Donde $f$ es la función a integrar, $a$ y $b$ son los límites de integración y $N$ es el número de puntos utilizados para la integración. Y que regrese el valor de la integral.

# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd

N = np.logspace(1, 6, 6)

table = pd.DataFrame(columns= ["Aproximación", "Error"], index=N)
table
# Out:
#           Aproximación Error
# 10.0               NaN   NaN
# 100.0              NaN   NaN
# 1000.0             NaN   NaN
# 10000.0            NaN   NaN
# 100000.0           NaN   NaN
# 1000000.0          NaN   NaN

# %%
def montecarlo(f, N, a, b) :
    u = np.random.uniform(a, b, N)
    return np.mean(f(u)*(b-a))

N
# Out:
# array([1.e+01, 1.e+02, 1.e+03, 1.e+04, 1.e+05, 1.e+06])

# %% [markdown]
# ### PRIMERA INTEGRAL

# %%
import numpy as np

a = .1
b = .3
def f(x) : 
    return (np.log(2 + np.sin(2*x**2)))/(x*np.e**-x**3)
for i in N : 
    aprox =  montecarlo(f, int(i), a, b)
    table.loc[i, "Aproximación"] = aprox
    table.loc[i, "Error"] = (0.806984064) - aprox

table
# Out:
#           Aproximación     Error
# 10.0          0.865795 -0.058811
# 100.0          0.81915 -0.012166
# 1000.0        0.803614   0.00337
# 10000.0       0.810782 -0.003798
# 100000.0      0.806139  0.000845
# 1000000.0     0.806868  0.000116

# %% [markdown]
# ### SEGUNDA INTEGRAL

# %%
import numpy as np

a = .3
b = .5

def f_2(x) : 
    return (np.log(2 + np.sin(2*x**2)))/(x*np.e**-x**3)

for i in N : 
    aprox =  montecarlo(f, int(i), a, b)
    table.loc[i, "Aproximación"] = aprox
    table.loc[i, "Error"] = (0.455534508) - aprox

table
# Out:
#           Aproximación     Error
# 10.0          0.455548 -0.000014
# 100.0         0.456371 -0.000836
# 1000.0        0.452908  0.002627
# 10000.0       0.455895 -0.000361
# 100000.0      0.455553 -0.000019
# 1000000.0     0.455543 -0.000008

# %% [markdown]
# ### TERCERA INTEGRAL

# %%
import numpy as np

a = .5
b = .7
def f_3(x) : 
    return (np.log(2 + np.sin(2*x**2)))/(x*np.e**-x**3)

for i in N : 
    aprox =  montecarlo(f, int(i), a, b)
    table.loc[i, "Aproximación"] = aprox
    table.loc[i, "Error"] = (0.40814318) - aprox

table
# Out:
#           Aproximación     Error
# 10.0          0.408381 -0.000237
# 100.0         0.407867  0.000277
# 1000.0        0.407965  0.000178
# 10000.0       0.408166 -0.000023
# 100000.0      0.408131  0.000012
# 1000000.0     0.408139  0.000004

# %% [markdown]
# ### CUARTA INTEGRAL

# %%
import numpy as np

a = .7
b = .9
def f_4(x) : 
    return (np.log(2 + np.sin(2*x**2)))/(x*np.e**-x**3)

for i in N : 
    aprox =  montecarlo(f, int(i), a, b)
    table.loc[i, "Aproximación"] = aprox
    table.loc[i, "Error"] = (0.4557415410) - aprox

table
# Out:
#           Aproximación     Error
# 10.0           0.46374 -0.007999
# 100.0          0.45595 -0.000208
# 1000.0        0.455765 -0.000024
# 10000.0       0.455869 -0.000128
# 100000.0      0.455818 -0.000077
# 1000000.0      0.45574  0.000002

# %% [markdown]
# ### QUINTA INTEGRAL

# %%
import numpy as np

a = .9
b = 1.1
def f_5(x) : 
    return (np.log(2 + np.sin(2*x**2)))/(x*np.e**-x**3)

for i in N : 
    aprox =  montecarlo(f, int(i), a, b)
    table.loc[i, "Aproximación"] = aprox
    table.loc[i, "Error"] = (0.5836821088) - aprox

table
# Out:
#           Aproximación     Error
# 10.0          0.595437 -0.011755
# 100.0         0.584152  -0.00047
# 1000.0        0.583454  0.000228
# 10000.0       0.584002  -0.00032
# 100000.0      0.583763 -0.000081
# 1000000.0     0.583675  0.000007

# %% [markdown]
# ## RESULTADO DE LAS INTEGRALES APROXIMADAS

# %%
# primera integral
y_punto1 = .1
int_1 = .806868
int_2 = .455543
int_3 = .408139
int_4 = .45574
int_5 = .583675

# %% [markdown]
# ###  En cada tabla vine la aproximacion de la funcion en diferentes intervalos. mas el error, Es mas exacto el resultado entre mas puntos utilicemos

# %%
import sympy as sp

# Definir la variable simbólica
x = sp.symbols('x')

# Definir la función a integrar
f = sp.log(2 + sp.sin(2*x**2))/(x*sp.exp(-x**3))

# Calcular la integral
resultado = sp.integrate(f, x)

# Imprimir el resultado
print(resultado)
# Out:
# Integral(exp(x**3)*log(sin(2*x**2) + 2)/x, x)

# %% [markdown]
# 2. Defina la función a integrar con argumentos de entrada $x$ y que regrese el valor de la derivada $\frac{dy}{dx}$.

# %% [markdown]
# 3. Encuentre la aproximación de las integrales con el método de Montecarlo de tipo 1. Escriba sus resultados en un _DataFrame_ de _pandas_.

# %% [markdown]
# 4. Use el teorema fundamental del cálculo (visto en cálculo integral) para escribir la secuencia de valores para la solución $y(x)$, esto es $[y(0.1), y(0.3), y(0.5), y(0.7), y(0.9), y(1.1)]$.
#
# Note que $y(0.3)=y(0.1)+\int_{0.1}^{0.3}\frac{dy}{dx}dx$, $y(0.5)=y(0.3)+\int_{0.3}^{0.5}\frac{dy}{dx}dx$, etc.

# %%
# Para el punto y(0.3)

y_punto3 = int_1 + y_punto1
y_punto3
# Out:
# 0.906868

# %%
# Para el punto y(0.5)

y_punto5 = int_2 + y_punto3
y_punto5
# Out:
# 2.273497

# %%
# Para el punto y(0.7)

y_punto7 = int_3 + y_punto5
y_punto7
# Out:
# 2.6816359999999997

# %%
# Para el punto y(0.9)

y_punto9 = int_4 + y_punto7
y_punto9
# Out:
# 3.1373759999999997

# %%
# Para el punto y(1.1)

y_punto1_1 = int_5 + y_punto9
y_punto1_1
# Out:
# 3.7210509999999997

# %% [markdown]
# ---
# ### Integración Montecarlo tipo 2 <font size='1'>(25 puntos)</font>
# Encuentre el área que cumpla $f(x,y)>v$, donde
# $$
# f(x,y)=e^{-0.05(x^2+y^2)}\sin(x^2+y^2),
# $$
# y $v=0.5$.

# %% [markdown]
# 1. Escriba la función que discrimine los puntos que satisfacen la restricción $f(x,y)>v$, con argumentos de entrada $x$ y $y$ y que regrese Verdadero o Falso.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

n = 500
x = np.random.uniform(-3, 1, n)
y = np.random.uniform(0, 4 , n)


def bernoulli2 (x, y):
    return np.exp(-0.05*(x**2 + y**2))*np.sin(x**2 + y**2) > 0.5

# %%
bernoulli2(x, y)
# Out:
# array([False, False, False, False, False, False,  True,  True, False,
#        False,  True, False,  True,  True,  True,  True,  True, False,
#        False, False, False,  True, False, False, False, False, False,
#         True, False,  True,  True, False,  True, False, False, False,
#        False, False,  True, False, False,  True, False, False, False,
#         True, False, False,  True, False,  True, False,  True,  True,
#         True, False,  True, False, False, False,  True, False, False,
#         True,  True, False, False, False, False, False, False,  True,
#        False, False,  True, False,  True,  True, False, False,  True,
#         True, False, False, False, False, False, False, False, False,
#         True, False,  True, False,  True, False, False,  True, False,
#        False, False,  True, False,  True,  True, False,  True, False,
#         True, False, False, False, False,  True,  True, False, False,
# ...

# %% [markdown]
# 2. Encuentre los límites de integración para $x$ y para $y$ que encierren el área deseada y grafique.

# %%
x = np.random.uniform(-3, 3, 100)
y = np.random.uniform(-3, 3, 100)

X,Y = np.meshgrid(x, y)

plt.figure()
plt.scatter(X,Y, c = bernoulli2(X,Y))

# %% [markdown]
# 3. Escriba la función para integrar con el método de Montecaralo de tipo 2 con argumentos de entrada $f$, $xmin$, $xmax$, $ymin$, $ymax$, y $N$. Donde $f$ es una función que define la región de integración; $xmin$, $xmax$, $ymin$ y $ymax$ definen los límites de integración y $N$ el número de puntos en $x$ y $y$ para usar en el método. Esta función debe regresar el valor de la integral.

# %%
def montecarlo2(region, ax, bx, ay, by, N):
    x = np.random.uniform(ax, bx, N)
    y = np.random.uniform(ay, by, N)
    B = region(x, y)
    AR = (bx - ax)*(by - ay)
    return np.mean(B)*AR

# %%
montecarlo2(bernoulli2,-3, 3, -3, 3, 10000)
# Out:
# 10.8648

# %% [markdown]
# 4. En un _DataFrame_ de _pandas_ escriba el valor de **las integrales** y la **estimación del error relativo** para $N=10^4,\, 10^5,\, 10^6$.

# %%
import numpy as np
def f(x, y) :
    return np.exp(-0.05*(x**2 + y**2))*np.sin(x**2 + y**2) > 0.5

N = 1000000
u = np.random.uniform(-3, 3, N)
v = np.random.uniform(-3, 3, N)
np.mean(f(u, v))*(3-(-3))**2
# Out:
# 10.925711999999999

# %%
import pandas as pd

N = [10**4, 10**5, 10**6]
tabla = pd.DataFrame(columns=["Aproximación", "Error"], index = N)
tabla
# Out:
#         Aproximación Error
# 10000            NaN   NaN
# 100000           NaN   NaN
# 1000000          NaN   NaN

# %%
def montecarlo2(region, ax, bx, ay, by, N):
    x = np.random.uniform(ax, bx, N)
    y = np.random.uniform(ay, by, N)
    B = region(x, y)
    AR = (bx - ax)*(by - ay)
    return np.mean(B)*AR

# %%
a = -3
b = 3

for i in N:
    aprox = montecarlo2(bernoulli2,-3, 3, -3, 3, 1000000)
    tabla.loc[i, "Aproximación"] = aprox
    tabla.loc[i, "Error"] = 10.925711999999 - aprox
tabla
# Out:
#         Aproximación     Error
# 10000      10.925928 -0.000216
# 100000     10.926576 -0.000864
# 1000000    10.930788 -0.005076

# %% [markdown]
# ---
# ### Generación de fractales <font size='1'>(25 puntos)</font>
#
# Los fractales de tipo Barnsley se generan con transformaciones afines con cierta probabilidad.
#
# Genere un helecho tridimensional con la ecuación:
# $$
# \begin{bmatrix}x_{k+1}\\y_{k+1}\\z_{k+1}
# \end{bmatrix}=A_i\begin{bmatrix}x_k\\y_k\\z_k\end{bmatrix}+b_i
# $$
# Y sus respectivas matrices:

# %%
import numpy as np

A0 = np.array([[0,0,0],[0,0.18,0],[0,0,0]])
b0 = np.array([0,0,0])

A1 = np.array([[0.85,0,0],[0,0.85,0.1],[0,-0.1,0.85]])
b1 = np.array([0,1.6,0])

A2 = np.array([[0.2,-0.2,0],[0.2,0.2,0],[0,0,0.3]])
b2 = np.array([0,0.8,0])

A3 = np.array([[-0.2,0.2,0],[0.2,0.2,0],[0,0,0.3]])
b3 = np.array([0,0.8,0])

# %% [markdown]
# cuya probabilidad es la misma para cada $i=\{0,1,2,3\}$. Use la función scatter de una proyección 3D sobre los ejes:
# ```
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
#
# fig=plt.figure()
# ax=fig.gca(projection='3d')
# ax.scatter(x,y,z)
# ```

# %% [markdown]
# # Metodo Vectorial

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import random
from mpl_toolkits.mplot3d import Axes3D

# %%
x = np.array([0, 0, 0])
x_historial = [0]
y_historial = [0]
z_historial = [0]

N = 100000
A_lista = [A0, A1, A2, A3]
b_lista = [b0, b1, b2, b3]

i = np.arange(4)
pi = [0.25, 0.25, 0.25, 0.25]

for k in range(N) :
    i_actual = random.choices(i, pi)[0]
    
    A = A_lista[i_actual]
    b = b_lista[i_actual]
    
    x = A@x + b
    x_historial.append(x[0])
    y_historial.append(x[1])
    z_historial.append(x[2])

# %%
fig = plt.figure()
ax = fig.gca(projection = '3d')
ax.scatter(x_historial, y_historial, z_historial, s = 1, c = "g")
# Out:
# C:\Users\domin\AppData\Local\Temp\ipykernel_19576\1182762865.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection = '3d')

# %% [markdown]
# ---
# ### Probabilidad Precio-Umbral <font size='1'>(25 puntos)</font>
#
# Suponga que desea invertir en **Oracle** o **Intel**. Evalúe la probabilidad de obtener un retorno del 10% en tres meses a partir del 31 de octubre del 2022.

# %% [markdown]
# 1. Describa una función para obtener los precios de cierre ajustados para dividendos y divisiones desde *YAHOO finance*, usando el paquete de *yfinance*, donde los argumentos de entrada sean los nombres de las empresas y las fechas de inicio y fin a los cuales se obtendrán los datos.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def getClose(names, start, end) :
    return yf.download(names, start = start, end = end)["Adj Close"]

# %% [markdown]
# 2. Obtenga los precios de cierre ajustados para Intel y Oracle desde el 31 de octubre de 2021 al 31 de octubre de 2022.

# %%
data_intc = getClose("INTC", "2020-11-05", "2022-11-05")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_orcl = getClose("ORCL", "2020-11-05", "2022-11-05")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# 3. Calcule el rendimiento **simple** para ambas empresas.

# %%
R_intc = (data_intc - data_intc.shift())/data_intc.shift()
R_orcl = (data_orcl - data_orcl.shift())/data_orcl.shift()

# %% [markdown]
# 4. Escriba una función que, dando como argumentos:
# * la media,
# * la desviación estandar,
# * la fecha de inicio,
# * **la fecha del fin de simulación** (**NO el número de días**) y
# * número de escenarios a simular;
#
# regrese en un _DataFrame_ de _pandas_ cuyo índice sea el rango de fechas dadas como argumentos.

# %%
def sim_r_intc(media, std, inicio, end, N) :
    m = 98
    r_intc = np.random.normal(media, std, size = (m, N))
    fechas_intc = pd.date_range(inicio, end)
    return pd.DataFrame(index = fechas_intc, data = r_intc)

# %%
def sim_r_orcl(media, std, inicio, end, N) :
    m = 98
    r_orcl = np.random.normal(media, std, size = (m, N))
    fechas_orcl = pd.date_range(inicio, end)
    return pd.DataFrame(index = fechas_orcl, data = r_orcl)

# %% [markdown]
# 5. Calcule la media y desviación estandar de los rendimientos y simule 100000 escenarios de rendimientos desde el 31 de octubre de 2022 al 5 de febrero de 2023.

# %%
R_intc_mean = R_intc.mean()
R_intc_std = R_intc.std()

R_orcl_mean = R_orcl.mean()
R_orcl_std = R_orcl.std()

# %%
r_simulados_intc = sim_r_intc(R_intc_mean, R_intc_std, "2022-11-05", "2023-02-10", 100000)
rendimientos_simulados_intc = (r_simulados_intc + 1).cumprod()
rendimientos_simulados_intc
# Out:
#                0         1         2         3         4         5      \
# 2022-11-05  0.977058  0.955632  1.013352  0.987917  1.026366  0.982570
# 2022-11-06  0.977847  0.949199  1.033028  0.979505  1.017462  0.986212
# 2022-11-07  0.994783  0.947301  1.049145  0.975390  1.021858  1.002975
# 2022-11-08  1.051764  0.950124  1.046805  0.990725  1.032640  1.006086
# 2022-11-09  1.009899  0.920889  1.110224  0.979099  1.022603  1.002172
# ...              ...       ...       ...       ...       ...       ...
# 2023-02-06  0.738915  1.046607  0.653289  0.784098  1.565796  1.149436
# 2023-02-07  0.738021  1.035507  0.651353  0.775203  1.540920  1.153934
# 2023-02-08  0.720012  1.015192  0.645361  0.768908  1.562201  1.147086
# 2023-02-09  0.688755  1.011988  0.632932  0.765627  1.614062  1.154093
# 2023-02-10  0.659762  1.021702  0.631682  0.767660  1.586304  1.154796
#
#                6         7         8         9      ...     99990     99991  \
# ...

# %%
r_simulados_orcl = sim_r_orcl(R_orcl_mean, R_orcl_std, "2022-11-05", "2023-02-10", 100000)
rendimientos_simulados_orcl = (r_simulados_orcl + 1).cumprod()
rendimientos_simulados_orcl
# Out:
#                0         1         2         3         4         5      \
# 2022-11-05  0.966188  0.991020  1.014359  1.021251  0.991937  1.018787
# 2022-11-06  0.946571  0.986820  1.021635  1.045840  1.004634  1.011259
# 2022-11-07  0.932702  0.989534  1.031678  1.055618  1.022064  0.980853
# 2022-11-08  0.929929  0.964662  1.029968  1.054273  1.037870  0.970522
# 2022-11-09  0.954605  0.964980  1.034832  1.057078  1.041572  0.955957
# ...              ...       ...       ...       ...       ...       ...
# 2023-02-06  1.088808  1.171574  1.396636  0.975678  1.233361  0.731478
# 2023-02-07  1.108534  1.132041  1.356643  0.968190  1.228426  0.744604
# 2023-02-08  1.095967  1.138371  1.370856  0.953346  1.201944  0.749035
# 2023-02-09  1.129911  1.168201  1.357480  0.950446  1.203906  0.753586
# 2023-02-10  1.137765  1.143209  1.442000  0.980141  1.204626  0.807452
#
#                6         7         8         9      ...     99990     99991  \
# ...

# %% [markdown]
# 6. Use los datos de simulación para obtener los precios proyectados al cierre para ambas empresas en estos meses.

# %%
precios_simulados_intc = rendimientos_simulados_intc * data_intc[-1]
precios_simulados_intc
# Out:
#                 0          1          2          3          4          5      \
# 2022-11-05  27.221336  26.624409  28.232528  27.523877  28.595097  27.374909
# 2022-11-06  27.243330  26.445177  28.780705  27.289529  28.347012  27.476395
# 2022-11-07  27.715180  26.392303  29.229742  27.174883  28.469494  27.943415
# 2022-11-08  29.302685  26.470946  29.164538  27.602107  28.769894  28.030087
# 2022-11-09  28.136306  25.656451  30.931429  27.278214  28.490243  27.921027
# ...               ...        ...        ...        ...        ...        ...
# 2023-02-06  20.586569  29.159032  18.200977  21.845371  43.623885  32.023883
# 2023-02-07  20.561639  28.849778  18.147030  21.597568  42.930833  32.149213
# 2023-02-08  20.059914  28.283769  17.980092  21.422174  43.523745  31.958411
# 2023-02-09  19.189071  28.194514  17.633816  21.330778  44.968602  32.153629
# 2023-02-10  18.381307  28.465144  17.598994  21.387409  44.195260  32.173230
#
# ...

# %%
precios_simulados_orcl = rendimientos_simulados_orcl * data_orcl[-1]
precios_simulados_orcl
# Out:
#                 0          1           2          3          4          5      \
# 2022-11-05  72.850911  74.723207   76.483017  77.002639  74.792403  76.816884
# 2022-11-06  71.371805  74.406585   77.031617  78.856698  75.749737  76.249264
# 2022-11-07  70.326073  74.611221   77.788881  79.593966  77.063950  73.956611
# 2022-11-08  70.116951  72.735815   77.659957  79.492575  78.255758  73.177668
# 2022-11-09  71.977543  72.759788   78.026676  79.704063  78.534909  72.079480
# ...               ...        ...         ...        ...        ...        ...
# 2023-02-06  82.096489  88.337090  105.306809  73.566480  92.995850  55.153684
# 2023-02-07  83.583823  85.356278  102.291326  73.001852  92.623743  56.143389
# 2023-02-08  82.636283  85.833594  103.362969  71.882601  90.626989  56.477525
# 2023-02-09  85.195666  88.082717  102.354418  71.663919  90.774910  56.820645
# 2023-02-10  85.787841  86.198308  108.727283  73.902994  90.829244  60.882169
#
# ...

# %% [markdown]
# 7. En un gráfico muestre la evolución de ambas probabilidades de obtener un retorno del 10%. ¿Cuál genera mayores expectativas?

# %%
valor_deseado_intc = data_intc[-1]*1.10
probabilidad_intc = (precios_simulados_intc >= valor_deseado_intc).mean(axis = 1)
plt.figure()
plt.plot(probabilidad_intc)
plt.grid()

# %% [markdown]
# ### Intel tiene una probabilidad del20%  en tener un rendimiento del 10 porciento asi que para mi no me arriesgaria a invertir

# %%
valor_deseado_orcl = data_orcl[-1]*1.10
probabilidad_orcl = (precios_simulados_orcl >= valor_deseado_orcl).mean(axis = 1)
plt.figure()
plt.plot(probabilidad_orcl)
plt.grid()

# %% [markdown]
# ### Oracle tiene una probabilidad del 40%  en tener un rendimiento del 10 porciento aqui es un poco mas probable de conseguirlo pero no invertiria

# %% [markdown]
# #### Extra <font size='1'>(10 puntos)</font>

# %% [markdown]
# Compara tus resultados con los valores verdaderos.

# %%
r_intc = np.log(data_intc /data_intc.shift())
r_orcl = np.log(data_orcl /data_orcl.shift())

# %%
def sim_r_intc_log(media, std, inicio, end, N) :
    m = 98
    r_intc = np.random.normal(media, std, size = (m, N))
    fechas_intc = pd.date_range(inicio, end)
    return pd.DataFrame(index = fechas_intc, data = r_intc)

# %%
def sim_r_orcl_log(media, std, inicio, end, N) :
    m = 98
    r_orcl = np.random.normal(media, std, size = (m, N))
    fechas_orcl = pd.date_range(inicio, end)
    return pd.DataFrame(index = fechas_orcl, data = r_orcl)

# %%
R_intc_mean = R_intc.mean()
R_intc_std = R_intc.std()

R_orcl_mean = R_orcl.mean()
R_orcl_std = R_orcl.std()

# %%
r_simulados_intc_log = sim_r_intc_log(R_intc_mean, R_intc_std, "2022-11-05", "2023-02-10", 100000)
rendimientos_simulados_intc_log = (r_simulados_intc + 1).cumprod()
rendimientos_simulados_intc_log
# Out:
#                0         1         2         3         4         5      \
# 2022-11-05  0.977058  0.955632  1.013352  0.987917  1.026366  0.982570
# 2022-11-06  0.977847  0.949199  1.033028  0.979505  1.017462  0.986212
# 2022-11-07  0.994783  0.947301  1.049145  0.975390  1.021858  1.002975
# 2022-11-08  1.051764  0.950124  1.046805  0.990725  1.032640  1.006086
# 2022-11-09  1.009899  0.920889  1.110224  0.979099  1.022603  1.002172
# ...              ...       ...       ...       ...       ...       ...
# 2023-02-06  0.738915  1.046607  0.653289  0.784098  1.565796  1.149436
# 2023-02-07  0.738021  1.035507  0.651353  0.775203  1.540920  1.153934
# 2023-02-08  0.720012  1.015192  0.645361  0.768908  1.562201  1.147086
# 2023-02-09  0.688755  1.011988  0.632932  0.765627  1.614062  1.154093
# 2023-02-10  0.659762  1.021702  0.631682  0.767660  1.586304  1.154796
#
#                6         7         8         9      ...     99990     99991  \
# ...

# %%
r_simulados_orcl_log = sim_r_orcl_log(R_orcl_mean, R_orcl_std, "2022-11-05", "2023-02-10", 100000)
rendimientos_simulados_orcl_log = (r_simulados_orcl + 1).cumprod()
rendimientos_simulados_orcl_log
# Out:
#                0         1         2         3         4         5      \
# 2022-11-05  0.966188  0.991020  1.014359  1.021251  0.991937  1.018787
# 2022-11-06  0.946571  0.986820  1.021635  1.045840  1.004634  1.011259
# 2022-11-07  0.932702  0.989534  1.031678  1.055618  1.022064  0.980853
# 2022-11-08  0.929929  0.964662  1.029968  1.054273  1.037870  0.970522
# 2022-11-09  0.954605  0.964980  1.034832  1.057078  1.041572  0.955957
# ...              ...       ...       ...       ...       ...       ...
# 2023-02-06  1.088808  1.171574  1.396636  0.975678  1.233361  0.731478
# 2023-02-07  1.108534  1.132041  1.356643  0.968190  1.228426  0.744604
# 2023-02-08  1.095967  1.138371  1.370856  0.953346  1.201944  0.749035
# 2023-02-09  1.129911  1.168201  1.357480  0.950446  1.203906  0.753586
# 2023-02-10  1.137765  1.143209  1.442000  0.980141  1.204626  0.807452
#
#                6         7         8         9      ...     99990     99991  \
# ...

# %%
precios_simulados_intc_log = rendimientos_simulados_intc * data_intc[-1]
precios_simulados_intc_log
# Out:
#                 0          1          2          3          4          5      \
# 2022-11-05  27.221336  26.624409  28.232528  27.523877  28.595097  27.374909
# 2022-11-06  27.243330  26.445177  28.780705  27.289529  28.347012  27.476395
# 2022-11-07  27.715180  26.392303  29.229742  27.174883  28.469494  27.943415
# 2022-11-08  29.302685  26.470946  29.164538  27.602107  28.769894  28.030087
# 2022-11-09  28.136306  25.656451  30.931429  27.278214  28.490243  27.921027
# ...               ...        ...        ...        ...        ...        ...
# 2023-02-06  20.586569  29.159032  18.200977  21.845371  43.623885  32.023883
# 2023-02-07  20.561639  28.849778  18.147030  21.597568  42.930833  32.149213
# 2023-02-08  20.059914  28.283769  17.980092  21.422174  43.523745  31.958411
# 2023-02-09  19.189071  28.194514  17.633816  21.330778  44.968602  32.153629
# 2023-02-10  18.381307  28.465144  17.598994  21.387409  44.195260  32.173230
#
# ...

# %%
precios_simulados_orcl_log = rendimientos_simulados_orcl * data_orcl[-1]
precios_simulados_orcl_log
# Out:
#                 0          1           2          3          4          5      \
# 2022-11-05  72.850911  74.723207   76.483017  77.002639  74.792403  76.816884
# 2022-11-06  71.371805  74.406585   77.031617  78.856698  75.749737  76.249264
# 2022-11-07  70.326073  74.611221   77.788881  79.593966  77.063950  73.956611
# 2022-11-08  70.116951  72.735815   77.659957  79.492575  78.255758  73.177668
# 2022-11-09  71.977543  72.759788   78.026676  79.704063  78.534909  72.079480
# ...               ...        ...         ...        ...        ...        ...
# 2023-02-06  82.096489  88.337090  105.306809  73.566480  92.995850  55.153684
# 2023-02-07  83.583823  85.356278  102.291326  73.001852  92.623743  56.143389
# 2023-02-08  82.636283  85.833594  103.362969  71.882601  90.626989  56.477525
# 2023-02-09  85.195666  88.082717  102.354418  71.663919  90.774910  56.820645
# 2023-02-10  85.787841  86.198308  108.727283  73.902994  90.829244  60.882169
#
# ...

# %%
valor_deseado_intc_log = data_intc[-1]*1.10
probabilidad_intc_log = (precios_simulados_intc_log >= valor_deseado_intc).mean(axis = 1)
plt.figure()
plt.plot(probabilidad_intc_log)
plt.grid()

# %%
valor_deseado_orcl_log = data_orcl[-1]*1.10
probabilidad_orcl_log = (precios_simulados_orcl_log >= valor_deseado_orcl).mean(axis = 1)
plt.figure()
plt.plot(probabilidad_orcl_log)
plt.grid()
